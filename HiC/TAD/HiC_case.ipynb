# %%
import cooler
import matplotlib.pyplot as plt
import pandas as pd
import trackc as tc
from matplotlib import cm

# %%
ZF_IgDn_500k = cooler.Cooler("/home/liminghong/work/Turner/F-IgD-.allValidPairs.mcool::/resolutions/500000")
ZM_IgDn_500k = cooler.Cooler("/home/liminghong/work/Turner/M-IgD-.allValidPairs.mcool::/resolutions/500000")
Z_IgDn_500k = cooler.Cooler("/home/liminghong/work/Turner/Z-IgD-.allValidPairs.mcool::/resolutions/500000")

ZF_naive_500k = cooler.Cooler("/home/liminghong/work/Turner/F-naive.allValidPairs.mcool::/resolutions/500000")
ZM_naive_500k = cooler.Cooler("/home/liminghong/work/Turner/M-naive.allValidPairs.mcool::/resolutions/500000")
Z_naive_500k = cooler.Cooler("/home/liminghong/work/Turner/Z-naive.allValidPairs.mcool::/resolutions/500000")

# %%
cmap = "YlOrRd"

# %%
fig, axs = tc.make_spec(figsize=(6, 3), height_ratios=[1], hspace=0.3)

tc.pl.mapC(ax=axs[0], mat=tc.tl.extractCisContact(clr=Z_naive_500k, region="X", extend=0), label="Z_naive", cmap=cmap, map_type="tri", height=350)
plt.savefig('case.X.pdf', format='pdf', bbox_inches='tight')
# Out:
# no max min range
# maxrange: 811.0 minrange: 7.0

# %%
fig, axs = tc.make_spec(figsize=(6, 7), height_ratios=[1, 1, 1, 1, 1, 1], hspace=0.3)

tc.pl.mapC(ax=axs[0], mat=tc.tl.extractCisContact(clr=ZF_IgDn_500k, region="X", extend=0), label="TS2F_IgDn", cmap=cmap, map_type="tri", height=150)
tc.pl.mapC(ax=axs[1], mat=tc.tl.extractCisContact(clr=ZM_IgDn_500k, region="X", extend=0), label="TS2M_IgDn", cmap=cmap, map_type="tri", height=150)
tc.pl.mapC(ax=axs[2], mat=tc.tl.extractCisContact(clr=Z_IgDn_500k, region="X", extend=0), label="TS2_IgDn", cmap=cmap, map_type="tri", height=150)

tc.pl.mapC(ax=axs[3], mat=tc.tl.extractCisContact(clr=ZF_naive_500k, region="X", extend=0), label="TS2F_naive", cmap=cmap, map_type="tri", height=150)
tc.pl.mapC(ax=axs[4], mat=tc.tl.extractCisContact(clr=ZM_naive_500k, region="X", extend=0), label="TS2M_naive", cmap=cmap, map_type="tri", height=150)
tc.pl.mapC(ax=axs[5], mat=tc.tl.extractCisContact(clr=Z_naive_500k, region="X", extend=0), label="TS2_naive", cmap=cmap, map_type="tri", height=150)

plt.savefig('case.X.TS2.pdf', format='pdf', bbox_inches='tight')
# Out:
# no max min range
# maxrange: 349.0 minrange: 2.0
# no max min range
# maxrange: 1151.0 minrange: 26.0
# no max min range
# maxrange: 577.0 minrange: 8.0
# no max min range
# maxrange: 730.9400000000023 minrange: 4.0
# no max min range
# maxrange: 1233.0 minrange: 26.0
# no max min range
# maxrange: 811.0 minrange: 7.0

# %%
ZF_IgDn_1k = cooler.Cooler("/home/liminghong/work/Turner/F-IgD-.allValidPairs.mcool::/resolutions/1000")
ZM_IgDn_1k = cooler.Cooler("/home/liminghong/work/Turner/M-IgD-.allValidPairs.mcool::/resolutions/1000")
Z_IgDn_1k = cooler.Cooler("/home/liminghong/work/Turner/Z-IgD-.allValidPairs.mcool::/resolutions/1000")

ZF_naive_1k = cooler.Cooler("/home/liminghong/work/Turner/F-naive.allValidPairs.mcool::/resolutions/1000")
ZM_naive_1k = cooler.Cooler("/home/liminghong/work/Turner/M-naive.allValidPairs.mcool::/resolutions/1000")
Z_naive_1k = cooler.Cooler("/home/liminghong/work/Turner/Z-naive.allValidPairs.mcool::/resolutions/1000")

ZF_IgDn_10k = cooler.Cooler("/home/liminghong/work/Turner/F-IgD-.allValidPairs.mcool::/resolutions/10000")
ZM_IgDn_10k = cooler.Cooler("/home/liminghong/work/Turner/M-IgD-.allValidPairs.mcool::/resolutions/10000")
Z_IgDn_10k = cooler.Cooler("/home/liminghong/work/Turner/Z-IgD-.allValidPairs.mcool::/resolutions/10000")

ZF_naive_10k = cooler.Cooler("/home/liminghong/work/Turner/F-naive.allValidPairs.mcool::/resolutions/10000")
ZM_naive_10k = cooler.Cooler("/home/liminghong/work/Turner/M-naive.allValidPairs.mcool::/resolutions/10000")
Z_naive_10k = cooler.Cooler("/home/liminghong/work/Turner/Z-naive.allValidPairs.mcool::/resolutions/10000")

# %%
# SLC25A6

region = "X:1505045-1511617"
height = 8


fig, axs = tc.make_spec(figsize=(6, 7), height_ratios=[1, 1, 1, 1, 1, 1], hspace=0.3)

tc.pl.mapC(ax=axs[0], mat=tc.tl.extractCisContact(clr=ZF_IgDn_1k, region=region, extend=0), label="ZF_IgDn", cmap=cmap, map_type="tri", height=height, trim_range=1)
tc.pl.mapC(ax=axs[1], mat=tc.tl.extractCisContact(clr=ZM_IgDn_1k, region=region, extend=0), label="ZM_IgDn", cmap=cmap, map_type="tri", height=height, trim_range=1)
tc.pl.mapC(ax=axs[2], mat=tc.tl.extractCisContact(clr=Z_IgDn_1k, region=region, extend=0), label="Z_IgDn", cmap=cmap, map_type="tri", height=height, trim_range=1)

tc.pl.mapC(ax=axs[3], mat=tc.tl.extractCisContact(clr=ZF_naive_1k, region=region, extend=0), label="ZF_naive", cmap=cmap, map_type="tri", height=height, trim_range=1)
tc.pl.mapC(ax=axs[4], mat=tc.tl.extractCisContact(clr=ZM_naive_1k, region=region, extend=0), label="ZM_naive", cmap=cmap, map_type="tri", height=height, trim_range=1)
tc.pl.mapC(ax=axs[5], mat=tc.tl.extractCisContact(clr=Z_naive_1k, region=region, extend=0), label="Z_naive", cmap=cmap, map_type="tri", height=height, trim_range=1)
# Out:
# maxrange: 68.0 minrange: 1.0
# maxrange: 132.0 minrange: 4.0
# maxrange: 57.0 minrange: 1.0
# maxrange: 141.0 minrange: 2.0
# maxrange: 189.0 minrange: 4.0
# maxrange: 113.0 minrange: 1.0

# %%
# SLC25A6

gene_bed12 = pd.read_table("Homo_sapiens.GRCh37.75.bed13", header=None)

fig, axs = tc.make_spec(figsize=(8, 8), height_ratios=[4, 4, 4, 4, 4, 4, 1], hspace=0.3)

region = "X:1500000-1520000"
height = 16
trim_range = 1
tc.pl.mapC(ax=axs[0], mat=tc.tl.extractCisContact(clr=ZF_IgDn_1k, region=region, extend=0), label="ZF_IgDn", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)
tc.pl.mapC(ax=axs[1], mat=tc.tl.extractCisContact(clr=ZM_IgDn_1k, region=region, extend=0), label="ZM_IgDn", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)
tc.pl.mapC(ax=axs[2], mat=tc.tl.extractCisContact(clr=Z_IgDn_1k, region=region, extend=0), label="Z_IgDn", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)

tc.pl.mapC(ax=axs[3], mat=tc.tl.extractCisContact(clr=ZF_naive_1k, region=region, extend=0), label="ZF_naive", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)
tc.pl.mapC(ax=axs[4], mat=tc.tl.extractCisContact(clr=ZM_naive_1k, region=region, extend=0), label="ZM_naive", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)
tc.pl.mapC(ax=axs[5], mat=tc.tl.extractCisContact(clr=Z_naive_1k, region=region, extend=0), label="Z_naive", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)

tc.pl.gene_track(
    ax=axs[6], bed12=gene_bed12, regions=region, line=3, gene_fontszie=10
)
tc.pl.scale_track(
    ax=axs[6], region=region, scale_adjust="kb", tick_pos="bottom", ratio2ax=1.2
)
plt.show()
# Out:
# maxrange: 68.0 minrange: 1.0
# maxrange: 132.0 minrange: 1.0
# maxrange: 57.0 minrange: 1.0
# maxrange: 141.0 minrange: 1.0
# maxrange: 189.0 minrange: 1.0
# maxrange: 113.0 minrange: 1.0

# %%
# SLC25A6

gene_bed12 = pd.read_table("Homo_sapiens.GRCh37.75.bed13", header=None)

fig, axs = tc.make_spec(figsize=(8, 12), height_ratios=[4, 4, 4, 4, 4, 4, 4], hspace=0.3)

region = "X:1350000-1630000"
height = 32
trim_range = 1
tc.pl.mapC(ax=axs[0], mat=tc.tl.extractCisContact(clr=ZF_IgDn_10k, region=region, extend=0), label="ZF_IgDn", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)
tc.pl.mapC(ax=axs[1], mat=tc.tl.extractCisContact(clr=ZM_IgDn_10k, region=region, extend=0), label="ZM_IgDn", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)
tc.pl.mapC(ax=axs[2], mat=tc.tl.extractCisContact(clr=Z_IgDn_10k, region=region, extend=0), label="Z_IgDn", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)

tc.pl.mapC(ax=axs[3], mat=tc.tl.extractCisContact(clr=ZF_naive_10k, region=region, extend=0), label="ZF_naive", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)
tc.pl.mapC(ax=axs[4], mat=tc.tl.extractCisContact(clr=ZM_naive_10k, region=region, extend=0), label="ZM_naive", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)
tc.pl.mapC(ax=axs[5], mat=tc.tl.extractCisContact(clr=Z_naive_10k, region=region, extend=0), label="Z_naive", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)

tc.pl.gene_track(
    ax=axs[6], bed12=gene_bed12, regions=region, line=3, gene_fontszie=10
)
tc.pl.scale_track(
    ax=axs[6], region=region, scale_adjust="Mb", tick_pos="bottom", ratio2ax=1.2
)
# Out:
# maxrange: 823.0 minrange: 1.0
# maxrange: 1735.0 minrange: 1.0
# maxrange: 723.0 minrange: 1.0
# maxrange: 1633.0 minrange: 1.0
# maxrange: 2160.0 minrange: 1.0
# maxrange: 1268.0 minrange: 1.0

# %%
# XIST

gene_bed12 = pd.read_table("Homo_sapiens.GRCh37.75.bed13", header=None)

fig, axs = tc.make_spec(figsize=(8, 8), height_ratios=[4, 4, 4, 4, 4, 4, 1], hspace=0.3)

region = "X:73030000-73076000"
height = 32
trim_range = 1
tc.pl.mapC(ax=axs[0], mat=tc.tl.extractCisContact(clr=ZF_IgDn_1k, region=region, extend=0), label="ZF_IgDn", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)
tc.pl.mapC(ax=axs[1], mat=tc.tl.extractCisContact(clr=ZM_IgDn_1k, region=region, extend=0), label="ZM_IgDn", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)
tc.pl.mapC(ax=axs[2], mat=tc.tl.extractCisContact(clr=Z_IgDn_1k, region=region, extend=0), label="Z_IgDn", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)

tc.pl.mapC(ax=axs[3], mat=tc.tl.extractCisContact(clr=ZF_naive_1k, region=region, extend=0), label="ZF_naive", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)
tc.pl.mapC(ax=axs[4], mat=tc.tl.extractCisContact(clr=ZM_naive_1k, region=region, extend=0), label="ZM_naive", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)
tc.pl.mapC(ax=axs[5], mat=tc.tl.extractCisContact(clr=Z_naive_1k, region=region, extend=0), label="Z_naive", cmap=cmap, map_type="tri", height=height, trim_range=trim_range)

tc.pl.gene_track(
    ax=axs[6], bed12=gene_bed12, regions=region, line=3, gene_fontszie=10
)
tc.pl.scale_track(
    ax=axs[6], region=region, scale_adjust="kb", tick_pos="bottom", ratio2ax=1.2
)
plt.show()
# Out:
# maxrange: 8.0 minrange: 1.0
# maxrange: 57.0 minrange: 1.0
# maxrange: 24.0 minrange: 1.0
# maxrange: 19.0 minrange: 1.0
# maxrange: 75.0 minrange: 1.0
# maxrange: 25.0 minrange: 1.0
